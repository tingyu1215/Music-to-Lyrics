# %%
# !pip3 install torch
from transformers import pipeline
classifier = pipeline(r'sentiment-analysis')
# Out:
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ck108sfg015\appdata\local\programs\python\python38-32\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ck108sfg015\\AppData\\Local\\Temp\\pip-install-w6cauxm7\\torch\\setup.py'"'"'; __file__='"'"'C:\\Users\\ck108sfg015\\AppData\\Local\\Temp\\pip-install-w6cauxm7\\torch\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\ck108sfg015\AppData\Local\Temp\pip-record-3o503ilh\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\ck108sfg015\appdata\local\programs\python\python38-32\Include\torch'
#          cwd: C:\Users\ck108sfg015\AppData\Local\Temp\pip-install-w6cauxm7\torch\
#     Complete output (23 lines):
#     running install
#     running build_deps
# ...
