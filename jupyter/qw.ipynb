# %%
import os
import pretty_midi
def runall(path):
    for folder in os.listdir(path) :
        print(path+'\\'+folder) ;
        if not os.path.isdir(path+'\\'+folder):
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == r'b0fdb8b9a502494edb048a5ba2c180af.mid':
                break
            if folder == r'd66b9c6c36a64a5dd1040008b828c419.mid':
                break
            if folder == r'b0fdb8b9a502494edb048a5ba2c180af.mid':
                break
            if folder == r'7a740d9a539336968dcff1f324f2b874.mid':
                break
            if folder == r'ce5beeae6280566fc87718ec7b261458.mid':
                break
            if folder == r'862b82b54c211fd12796bb6c23282e11.mid':
                break
            if folder == r'9f79f5113aa40a71564937281bcc077e.mid':
                break
            if folder == r'1d2b92aa9e454280cca21fae99ebce8e.mid':
                break
            if folder == r'913503a9957064c04d5cc72e351bf485.mid':
                break
            if folder == r'2cdb25a9abc795d12679c3f6abc2b212.mid':
                break
            if folder == r'3056c10a32eae29dc187cb8c742ecbb7.mid':
                break
            if folder == r'62f4d8788ba05f3c49ebfa6fc9164621.mid':
                break
            if folder == r'2cdb25a9abc795d12679c3f6abc2b212.mid':
                break
            if folder == r'c7322533636b55d8eb7feb62bb7a2256.mid':
                break
            if folder == r'2a75cbdeea76ef922fae53f93ab09bc9.mid':
                break
            if folder == r'7d36cb4fb85945912f1919237ba36f2b.mid':
                break
            if folder == r'ef01e7ac175225f00a2a907529a26039.mid':
                break
            if folder == r'e6f0596983429cbd1b693abd655d71b6.mid':
                break
            if folder == r'539e5566a50e16fc46c35f118ae3eca8.mid':
                break
            if folder == r'a8f1a2152eb99929b4992361e1fd73f9.mid':
                break
            if folder == r'6a19e9c5d142647bed0cf8b26755959f.mid':
                break
            if folder == r'2d5f3ae1620e208272d7c030d8413672.mid':
                break
            if folder == r'546df09d78a32141369fcc17ff51cec0.mid':
                break
            if folder == r'eae91f45f47dc818aed7d6e2705adcf2.mid':
                break
            if folder == r'a5c32497c73668df835d1f96114c84c4.mid':
                break
            if folder == r'572b7562af9fe77d917bd5a6ef252ddd.mid':
                break
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            lyric= pretty_midi.PrettyMIDI(path+'\\'+folder).lyrics ;
            #if lyric : 
                #print(lyric) ;
                #count+=1 ;
        else :
            runall(path+'\\'+folder) ;
runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P'   )
# Out:
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\L
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\L\TRAPLMG128F428E2E6
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\L\TRAPLMG128F428E2E6\bdc67b45d8057c8abc5f32416a4cdbf4.mid
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\L\TRAPLDH128F428C595
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\L\TRAPLDH128F428C595\074194bc3ddf82d1a4d597b2ecf27558.mid
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\L\TRAPLDH128F428C595\d9544d7f3a4642a3e096c97aa7d04603.mid
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\J
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\J\TRAPJYG128F427F0F7
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\J\TRAPJYG128F427F0F7\38fce88baa7b7ce74c3349f4e7a9d548.mid
# D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\A\P\C
# ...
