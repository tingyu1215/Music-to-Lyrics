# %%
import os
import pretty_midi
print(pretty_midi.PrettyMIDI (r'D:\0a6358b585af7d89eee70d7ff8150f84.mid').lyrics)
# Out:
# ", time=343.05690325), Lyric(text="Love ", time=350.49640450000004), Lyric(text="is ", time=350.63753325000005), Lyric(text="in ", time=350.857290875), Lyric(text="the ", time=351.1163629375), Lyric(text="air ", time=351.220193375)]
