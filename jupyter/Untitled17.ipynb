# %%
import os
import pretty_midi

def runall(path):
    for folder in os.listdir(path) :
        if not os.path.isdir(path+'\\'+folder):
            lyric= pretty_midi.PrettyMIDI(path+'\\'+folder).lyrics ;
            if lyric : 
                print(path+'\\'+folder)
                print(lyric)
        else :
            runall(path+'\\'+folder)
            
runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-0ac69b35597d> in <module>
#      12             runall(path+'\\'+folder)
#      13
# ---> 14 runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')
#
# <ipython-input-1-0ac69b35597d> in runall(path)
#      10                 print(lyric)
#      11         else :
# ---> 12             runall(path+'\\'+folder)
#      13
#      14 runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')
#
# <ipython-input-1-0ac69b35597d> in runall(path)
#      10                 print(lyric)
#      11         else :
# ---> 12             runall(path+'\\'+folder)
#      13
#      14 runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')
#
# <ipython-input-1-0ac69b35597d> in runall(path)
#      10                 print(lyric)
#      11         else :
# ---> 12             runall(path+'\\'+folder)
#      13
#      14 runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')
#
# <ipython-input-1-0ac69b35597d> in runall(path)
#      10                 print(lyric)
#      11         else :
# ---> 12             runall(path+'\\'+folder)
#      13
#      14 runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')
#
# <ipython-input-1-0ac69b35597d> in runall(path)
#       5     for folder in os.listdir(path) :
#       6         if not os.path.isdir(path+'\\'+folder):
# ----> 7             lyric= pretty_midi.PrettyMIDI(path+'\\'+folder).lyrics ;
#       8             if lyric :
#       9                 print(path+'\\'+folder)
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\pretty_midi\pretty_midi.py in __init__(self, midi_file, resolution, initial_tempo)
#      58             if isinstance(midi_file, six.string_types):
#      59                 # If a string was given, pass it as the string filename
# ---> 60                 midi_data = mido.MidiFile(filename=midi_file)
#      61             else:
#      62                 # Otherwise, try passing it in as a file pointer
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug, clip)
#     314         elif self.filename is not None:
#     315             with io.open(filename, 'rb') as file:
# --> 316                 self._load(file)
#     317
#     318     def add_track(self, name=None):
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in _load(self, infile)
#     351                 self.tracks.append(read_track(infile,
#     352                                               debug=self.debug,
# --> 353                                               clip=self.clip))
#     354                 # TODO: used to ignore EOFError. I hope things still work.
#     355
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in read_track(infile, debug, clip)
#     216             # TODO: I'm not quite clear on the difference between
#     217             # f0 and f7 events.
# --> 218             msg = read_sysex(infile, delta)
#     219         else:
#     220             msg = read_message(infile, status_byte, peek_data, delta, clip)
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in read_sysex(infile, delta)
#     150         data = data[:-1]
#     151
# --> 152     return Message('sysex', data=data, time=delta)
#     153
#     154
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\messages\messages.py in __init__(self, type, **args)
#      86         if type == 'sysex':
#      87             msgdict['data'] = SysexData(convert_py2_bytes(msgdict['data']))
# ---> 88         check_msgdict(msgdict)
#      89         vars(self).update(msgdict)
#      90
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\messages\checks.py in check_msgdict(msgdict)
#      97                 '{} message has no attribute {}'.format(spec['type'], name))
#      98
# ---> 99         check_value(name, value)
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\messages\checks.py in check_value(name, value)
#      84
#      85 def check_value(name, value):
# ---> 86     _CHECKS[name](value)
#      87
#      88
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\messages\checks.py in check_data(data_bytes)
#      35 def check_data(data_bytes):
#      36     for byte in convert_py2_bytes(data_bytes):
# ---> 37         check_data_byte(byte)
#      38
#      39
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\messages\checks.py in check_data_byte(value)
#      56         raise TypeError('data byte must be int')
#      57     elif not 0 <= value <= 127:
# ---> 58         raise ValueError('data byte must be in range 0..127')
#      59
#      60
#
# ValueError: data byte must be in range 0..127
