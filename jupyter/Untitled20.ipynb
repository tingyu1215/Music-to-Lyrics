# %%
import os
import pretty_midi
'''
path = r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched' ;
files= os.listdir(path) #得到資料夾下的所有檔名稱
s = []
for file in files: #遍歷資料夾
    if not os.path.isdir(file): #判斷是否是資料夾,不是資料夾才打開
        data = pretty_midi.PrettyMIDI(path+"\\"+file)
        print(data.lyrics)
    else:
        path2=(path+"\\"+file)
        files2=os.listdir(path2)
        for file in files2:
            if not os.path.isdir(file):
                data = pretty_midi.PrettyMIDI(path2+"\\"+file)
                print(data.lyrics)
            else:
                path3=(path2+"\\"+file)
                files3=os.listdir(path3)
                for file in files3:
                    if not os.path.isdir(file):
                        data = pretty_midi.PrettyMIDI(path3+"\\"+file)
                        print(data.lyrics)
                    else:
                        path4=(path3+"\\"+file)
                        files4=os.listdir(path4)
                        for file in files4:
                            if not os.path.isdir(file):
                                data = pretty_midi.PrettyMIDI(path4+"\\"+file)
                                print(data.lyrics)
                            else:
                                path5=(path4+"\\"+file)
                                files5=os.listdir(path5)
                                for file in files5:
                                    if not os.path.isdir(file):
                                        data = pretty_midi.PrettyMIDI(path5+"\\"+file)
                                        print(data.lyrics)
'''
##
def runall(path):
    for folder in os.listdir(path) :
        if not os.path.isdir(path+'\\'+folder):
            if folder == r'75aa9bfa965f096ce7cff2cd0d68fc98.mid':
                break
            if folder == 'b0fdb8b9a502494edb048a5ba2c180af.mid':
                break
            if folder == 'd66b9c6c36a64a5dd1040008b828c419.mid':
                break
            if folder == 'b0fdb8b9a502494edb048a5ba2c180af.mid':
                break
            #if byte > 127:
                break
            #print(path+'\\'+folder) ;
            lyric= pretty_midi.PrettyMIDI(path+'\\'+folder).lyrics ;
            #if lyric : 
                #print(lyric) ;
                #count+=1 ;
        else :
            runall(path+'\\'+folder) ;
            
            
#pretty_midi.PrettyMIDI(r"D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\L\M\H\TRLMHJL12903CC6D50\75aa9bfa965f096ce7cff2cd0d68fc98.mid") ;
            
runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')        ;
#print(count) ;
#000
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-35d33290d207> in <module>
#      63 #pretty_midi.PrettyMIDI(r"D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched\L\M\H\TRLMHJL12903CC6D50\75aa9bfa965f096ce7cff2cd0d68fc98.mid") ;
#      64
# ---> 65 runall( r'D:\download\lmd_matched (1).tar\lmd_matched (1)\lmd_matched')        ;
#      66 #print(count) ;
#      67 #000
#
# <ipython-input-2-35d33290d207> in runall(path)
#      58                 #count+=1 ;
#      59         else :
# ---> 60             runall(path+'\\'+folder) ;
#      61
#      62
#
# <ipython-input-2-35d33290d207> in runall(path)
#      58                 #count+=1 ;
#      59         else :
# ---> 60             runall(path+'\\'+folder) ;
#      61
#      62
#
# <ipython-input-2-35d33290d207> in runall(path)
#      58                 #count+=1 ;
#      59         else :
# ---> 60             runall(path+'\\'+folder) ;
#      61
#      62
#
# <ipython-input-2-35d33290d207> in runall(path)
#      58                 #count+=1 ;
#      59         else :
# ---> 60             runall(path+'\\'+folder) ;
#      61
#      62
#
# <ipython-input-2-35d33290d207> in runall(path)
#      53                 break
#      54             #print(path+'\\'+folder) ;
# ---> 55             lyric= pretty_midi.PrettyMIDI(path+'\\'+folder).lyrics ;
#      56             #if lyric :
#      57                 #print(lyric) ;
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\pretty_midi\pretty_midi.py in __init__(self, midi_file, resolution, initial_tempo)
#      58             if isinstance(midi_file, six.string_types):
#      59                 # If a string was given, pass it as the string filename
# ---> 60                 midi_data = mido.MidiFile(filename=midi_file)
#      61             else:
#      62                 # Otherwise, try passing it in as a file pointer
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug, clip)
#     314         elif self.filename is not None:
#     315             with io.open(filename, 'rb') as file:
# --> 316                 self._load(file)
#     317
#     318     def add_track(self, name=None):
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in _load(self, infile)
#     351                 self.tracks.append(read_track(infile,
#     352                                               debug=self.debug,
# --> 353                                               clip=self.clip))
#     354                 # TODO: used to ignore EOFError. I hope things still work.
#     355
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in read_track(infile, debug, clip)
#     218             msg = read_sysex(infile, delta)
#     219         else:
# --> 220             msg = read_message(infile, status_byte, peek_data, delta, clip)
#     221
#     222         track.append(msg)
#
# C:\ProgramData\Anaconda3\envs\opencv\lib\site-packages\mido\midifiles\midifiles.py in read_message(infile, status_byte, peek_data, delta, clip)
#     134         for byte in data_bytes:
#     135             if byte > 127:
# --> 136                 raise IOError('data byte must be in range 0..127')
#     137
#     138     return Message.from_bytes([status_byte] + data_bytes, time=delta)
#
# OSError: data byte must be in range 0..127
